# %%
# %matplotlib inline
import pandas as pd
x=[1,2,3,4,5]
y=[9,8,7,6,5]
sy=pd.DataFrame(x)
df = pd.DataFrame({
    'X': [1, 2, 3, 4, 5],
    'Y': [2, 4, 6, 10, 15]
})
print(df)
df.plot()
# Out:
#    X   Y
# 0  1   2
# 1  2   4
# 2  3   6
# 3  4  10
# 4  5  15
# <Axes: >
